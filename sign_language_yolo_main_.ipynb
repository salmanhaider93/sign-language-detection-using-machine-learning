# %%
## the code was created to train the images colllected with YOLO
# Out:
# Mounted at /content/drive

# %%
#mounnted to my google drive 
from google.colab import drive
drive.mount('/content/drive')

# %%
#code for installing YOLO API
#!git clone 'https://github.com/AlexeyAB/darknet' '/content/drive/MyDrive/yolo_custom_model_Training/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo_custom_model_Training/darknet'...
# remote: Enumerating objects: 14949, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 14949 (delta 33), reused 51 (delta 24), pack-reused 14884
# Receiving objects: 100% (14949/14949), 13.42 MiB | 4.33 MiB/s, done.
# Resolving deltas: 100% (10153/10153), done.
# Checking out files: 100% (2023/2023), done.

# %%
#directing to my drive
# %cd '/content/drive/MyDrive/yolo_custom_model_Training'
# Out:
# /content/drive/MyDrive/yolo_custom_model_Training

# %%
# !ls
# Out:
# backup	custom_data.zip  custom_weight	darknet

# %%
#enabling GPU
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/drive/MyDrive/yolo_custom_model_Training/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
#!python custom_data/creating-files-data-and-name.py

# %%
#!python custom_data/creating-train-and-test-txt-files.py

# %%
#!darknet/darknet
# Out:
# /bin/bash: darknet/darknet: Not a directory

# %%
# %cd '/content/drive/My Drive/yolo_custom_model_Training'
# Out:
# /content/drive/My Drive/yolo_custom_model_Training

# %%
# !ls
# Out:
# backup	custom_data  custom_data.zip  custom_weight  darknet

# %%
#Training the model with YOLO API
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.823141), count: 1, class_loss = 0.002968, iou_loss = 0.160518, total_loss = 0.163486
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 58184, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.021564, iou_loss = 0.000000, total_loss = 0.021564
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.754366), count: 1, class_loss = 0.030088, iou_loss = 0.114166, total_loss = 0.144254
# ...
